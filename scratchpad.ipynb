# %%
import yaml

from src.config import Config
from src.data import load_ihdp, make_ihdp_confounded

# %%
with open("config/ihdp.yaml") as f:
    cfg = Config.model_validate(yaml.safe_load(f))

# Load data and confound it
train_ds, val_ds, test_ds, ytrain_std = load_ihdp(
    cfg.data.path,
    replication=1,
    train_ratio=cfg.data.train_ratio,
    test_ratio=cfg.data.test_ratio,
)
train_ds_conf, val_ds_conf, test_ds_conf = (
    make_ihdp_confounded(ds, effect=cfg.data.confounder_effect)
    for ds in (train_ds, val_ds, test_ds)
)

# %%
print("Unconfounded datasets:")
for ds in (train_ds, val_ds, test_ds):
    print(
        f"  Treatment rate: {ds.a.mean().item():.3f},"
        f" mu0 mean: {ds.mu0.mean().item():.3f},"
        f" mu1 mean: {ds.mu1.mean().item():.3f}"
    )
# Out:
# Unconfounded datasets:
#   Treatment rate: 0.383, mu0 mean: -0.617, mu1 mean: 1.029
#   Treatment rate: 0.378, mu0 mean: -0.650, mu1 mean: 1.022
#   Treatment rate: 0.385, mu0 mean: -0.679, mu1 mean: 1.011

# %%
print("Confounded datasets:")
for ds in (train_ds_conf, val_ds_conf, test_ds_conf):
    print(
        f"  Treatment rate: {ds.a.mean().item():.3f},"
        f" mu0 mean: {ds.mu0.mean().item():.3f},"
        f" mu1 mean: {ds.mu1.mean().item():.3f}"
    )
# Out:
# Confounded datasets:
#   Treatment rate: 0.489, mu0 mean: -0.379, mu1 mean: 1.118
#   Treatment rate: 0.507, mu0 mean: -0.447, mu1 mean: 1.099
#   Treatment rate: 0.541, mu0 mean: -0.457, mu1 mean: 1.094
