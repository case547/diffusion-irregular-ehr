# %%
import pandas as pd

# %%
df = pd.read_csv("preds_diffpo_full_2026-07-24T13_13_03.csv")

df.describe()
# Out:
#               mu0         mu1      y0_mean       y1_mean        y0_std  \
# count  113.000000  113.000000   113.000000    113.000000    113.000000
# mean    -0.302204    1.510151  3003.073687  -1563.455888   7291.804707
# std      0.508218    0.201088  1159.560701   4610.789299   1341.247958
# min     -1.002790    1.109215   549.100464 -12444.683594   4064.914795
# 25%     -0.686952    1.363741  2234.404297  -4809.096680   6281.509277
# 50%     -0.427247    1.500796  2841.530029  -1334.484375   7277.513184
# 75%      0.055454    1.679935  3750.992188   1011.870178   8177.951172
# max      1.121894    1.925937  6827.848145  12336.032227  10593.470703
#
#              y1_std      y0_lo95       y0_hi95       y1_lo95       y1_hi95
# count    113.000000   113.000000    113.000000    113.000000    113.000000
# mean   33252.002610 -5889.559838  19398.907581 -63288.766386  57882.585868
# std     3308.078787  1206.743225   4474.088166  10166.885460   9601.896276
# ...
